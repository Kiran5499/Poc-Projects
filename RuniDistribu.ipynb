# %%
# RUNIF

# Uniform Distribution
# runif generates random deviates

# generate uniform randum numbers with runif(…)

r <- runif(10, -1, 1)
r
# Out:
#  [1]  0.89382649  0.02146709 -0.21315889  0.81747428 -0.93988492  0.99227418
#  [7] -0.81838754 -0.26171707 -0.86403925  0.56165497

# %%
r <- runif(1000, 0, 1)

plot(1:1000, r)
# Out:
# plot without title

# %%
runif(4, min=3, max=7)
# Out:
# [1] 6.037895 3.800882 4.449116 3.500965

# %%
# Two standard normal variates with a mean of 42 and a standard deviation of 9: rnorm(2, mean=42, sd=9).

rnorm(5, mean=42, sd=9)
# Out:
# [1] 35.37519 33.95938 40.81747 61.49867 42.79245

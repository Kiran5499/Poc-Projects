# %%
# Install.packages("ggmap")

#library("devtools")
# devtools::install_github("dkahle/ggmap")


library(ggmap)
library(tidyverse)

api_key <- "AIzaSyClJVqN08I1oNYLYRw0mh_HCHP9rYoPZCw"

register_google(key = api_key)
ggmap_credentials()

map2 <- get_map(
  location = c(lon = 144.9965 , lat = -37.8021),
  #location = "Australia",
  zoom = 16,
  scale = 2,
  maptype = c(
    
    "roadmap"
    
  ),
  source = c("google"),
  api_key
)

ggmap(map2)

(wh <- as.numeric(geocode("the white house, dc")))

mapdist(c(77.37484741, 28.14183998),c(77.37471008,29.14178085))

from <- c("houston, texas", "dallas")
to <- "waco, texas"
mapdist(from, to)
mapdist(from, to, mode = "bicycling")
mapdist(from, to, mode = "walking")
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v tibble  1.4.2     v purrr   0.2.5
# v tidyr   0.8.2     v dplyr   0.7.8
# v readr   1.3.0     v stringr 1.3.1
# v tibble  1.4.2     v forcats 0.3.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# Google -
#    key : AIzaSyClJVqN08I1oNYLYRw0mh_HCHP9rYoPZCw
#    account_type : standard
#    day_limit : 2500
#    second_limit : 50
#    client :
#    signature :
# Source : https://maps.googleapis.com/maps/api/staticmap?center=-37.8021,144.9965&zoom=16&size=640x640&scale=2&maptype=roadmap&language=en-EN&key=AIzaSyClJVqN08I1oNYLYRw0mh_HCHP9rYoPZCw
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=the%20white%20house%2C%20dc&key=AIzaSyClJVqN08I1oNYLYRw0mh_HCHP9rYoPZCw
# [1] -77.03653  38.89768
# ...

# %%
#install.packages("tidyverse")

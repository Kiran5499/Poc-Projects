# %%
data <- read.csv("C:\\Users\\pavan\\Downloads\\creditcard.csv", header = TRUE,
                 stringsAsFactors = FALSE,
                 strip.white = TRUE ,
                 sep = ',')

str(data)

library("sqldf")
data <- sqldf("select * from data where Class=1")
str(data)
data <- data[,2:30]
str(data)

# %%
##
prcomp(data, scale = TRUE)

##
df2 <- prcomp(data, scale = TRUE)
summary(df2)

##
library("factoextra")
var <- get_pca_var(df2)
var
head(var$contrib)

##
fviz_cos2(df2, choice = "var", axes = 1:2)

##
library("corrplot")
corrplot(var$cos2, is.corr=FALSE) 

##
library("corrplot")
corrplot(var$contrib, is.corr=FALSE)  


##
# Contributions of variables to PC1
fviz_contrib(df2, choice = "var", axes = 1, top = 10)
# Contributions of variables to PC2
fviz_contrib(df2, choice = "var", axes = 2, top = 10)

##
biplot(df2, scale = 0)

##
library("FactoMineR")
res.pca = PCA(data)
res.desc <- dimdesc(res.pca, axes = c(1,2), proba = 0.05)
# # Description of dimension 1
res.desc$Dim.1

##

# Total contribution on PC1 and PC2
fviz_contrib(df2, choice = "var", axes = 2, top=5)

# %%
data < na.omit(data)

data$class2 <- as.factor(data$Class)
ncol(data)
head(data)
head(data$class2)

iris.pca <- PCA(data[,c(-31,-32,-33)], graph = FALSE)
fviz_pca_ind(iris.pca,
             geom.ind = "point", # show points only (nbut not "text")
             col.ind = data$class2, # color by groups
             palette = c("#00AFBB", "#E7B800"),
             addEllipses = TRUE, # Concentration ellipses
             legend.title = "Groups"
)
